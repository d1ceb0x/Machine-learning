# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.metrics import classification_report
from sklearn.metrics import root_mean_squared_log_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_percentage_error
from sklearn.metrics import root_mean_squared_log_error
from sklearn.metrics import root_mean_squared_error
from sklearn.preprocessing import StandardScaler
import scipy.stats as stats

# %% [markdown]
# This is the model comparisons for each model's percentage error

# %%
LrMAPE = 0.00042218276429515636
PrMAPE = 0.00018930766407996023
SvrMAPE = 0.010894918979210516
DtrMAPE = 0.0004955761757413668
RfrMAPE = 0.0002870032245147918
nnMAPE = 0.0003693231923207831
models = ['Linear Regression', 'Polynomial Regression', 'Support Vector Regression', 'Decision Tree Regression', 'Random Forest Regression', 'Neural Network']
mape_values = [0.00042218276429515636, 0.00018930766407996023, 0.010894918979210516, 0.0004955761757413668, 0.0002870032245147918, 0.0003693231923207831]

# %%
plt.figure(figsize=(10, 6))
plt.bar(models, mape_values, color='blue')
plt.xlabel('Regression Models')
plt.ylabel('Mean Absolute Percentage Error (MAPE)')
plt.title('Comparison of Percentage error for Different Regression Models')
plt.xticks(rotation=45, ha='right')
plt.yticks(np.arange(0.0, 0.013, 0.001), fontsize=10) 
average_mape = np.mean(mape_values)
plt.axhline(y=average_mape, color='red', linestyle='--', linewidth=0.8, label='Average MAPE')
plt.tight_layout()
plt.show()
#We can see that support vector regression has a way higher percentage error than the rest, yet still relitively low

# %% [markdown]
# This is the model comparisons for each model's R^2 scores

# %%
LrR2 = 0.9999286563355192
PrR2 = 0.999976747986906
SvrR2 = 0.9460415624591131
DtrR2 = 0.9996579257082148
RfrR2 = 0.9996675548034768
nnR2 = 0.9999343981972776
models = ['Linear Regression', 'Polynomial Regression', 'Support Vector Regression', 'Decision Tree Regression', 'Random Forest Regression', 'Neural Network']
r2_scores = [0.9999286563355192, 0.999976747986906, 0.9460415624591131, 0.9996579257082148, 0.9996675548034768, 0.9999343981972776]


plt.figure(figsize=(8, 5))
plt.bar(models, r2_scores, color='green')  
plt.xlabel('Regression Models', fontsize=12)
plt.ylabel('R-squared (R2) Score', fontsize=12)
plt.title('Comparison of R-squared (R2) Scores for Different Regression Models', fontsize=14)
plt.xticks(rotation=45, ha='right', fontsize=10)
plt.yticks(fontsize=10)
plt.tight_layout()
plt.yticks(np.arange(0.0, 1.1, 0.05), fontsize=8) 
average_r2_score = np.mean(r2_scores)
plt.axhline(y=average_r2_score, color='red', linestyle='--', linewidth=0.8, label='Average R^2 score')
plt.legend() 
plt.tight_layout()
plt.show()
#The R^2 score denotes the correlation coefficient. The closer it is to 1, the more accurate is it. 
#The polynomail regression and Neural Network hold the highest accuracy

# %% [markdown]
# This is the model comparisons for each model's F - test scores

# %%
LrF = 0.9999634387091962
PrF = 1.0000363199253932
SvrF = 0.9511276561289465
DtrF = 0.9996579257082148
RfrF = 0.9996675548034768
nnF = 1.0010741650406332
models = ['Linear Regression', 'Polynomial Regression', 'Support Vector Regression', 'Decision Tree Regression', 'Random Forest Regression', 'Neural Network']
f_test_scores = [0.9999634387091962, 1.0000363199253932, 0.9511276561289465, 0.9996579257082148, 0.9996675548034768, 1.0010741650406332]


plt.figure(figsize=(8, 5))
bars = plt.bar(models, f_test_scores, color='purple')  
plt.xlabel('Regression Models', fontsize=12)
plt.ylabel('F-test Score', fontsize=12)
plt.title('Comparison of F-test Scores for Different Regression Models', fontsize=14)
plt.xticks(rotation=45, ha='right', fontsize=10)
plt.yticks(np.arange(0.0, 1.05, 0.05), fontsize=8)  # Specify tick locations and labels manually
highest_index = np.argmax(f_test_scores)
average_f_test_score = np.mean(f_test_scores)
plt.axhline(y=average_f_test_score, color='red', linestyle='--', linewidth=0.8, label='Average F-test Score')
plt.legend()  
plt.tight_layout()
plt.show()
#The F test score compares the variances, or the "Noise and signal". The close the F value is to 1, the better quality our predictions are
#Currently the Polynomial regression and the linear regression hold the best noise to signal ratio
